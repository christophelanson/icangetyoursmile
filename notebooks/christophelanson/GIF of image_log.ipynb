# %%
import pickle
from PIL import Image
import matplotlib.pyplot as plt
import imageio

# %%
with open('./image_logs/storage_U-net-christophe.pickle', 'rb') as handle:
    image_log = pickle.load(handle)

# %%
len(image_log)
# Out:
# 10

# %%
image_nb = 4
log_nb = 9
plt.imshow(image_log[log_nb][image_nb])
plt.axis('off');

# %%
image_nb = 2
anim_file = 'Unet.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
  for img_nb in range(len(image_log)):
    writer.append_data(image_log[img_nb][image_nb])

# %%
import tensorflow_docs.vis.embed as embed
embed.embed_file(anim_file)
# Out:
# 2022-03-10 10:40:18.818164: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-10 10:40:18.819130: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# <img src="data:image/gif;base64,..."/>

# %%
anim_files = []
for image_nb in range(5):
    anim_file = f'Unet{image_nb}.gif'
    anim_files.append(anim_file)
    with imageio.get_writer(anim_file, mode='I') as writer:
      for img_nb in range(len(image_log)):
        writer.append_data(image_log[img_nb][image_nb])

# %%
import tensorflow_docs.vis.embed as embed
embed.embed_file(anim_files[0])
# Out:
# <img src="data:image/gif;base64,..."/>

# %%
embed.embed_file(anim_files[1])
# Out:
# <img src="data:image/gif;base64,..."/>

# %%
embed.embed_file(anim_files[2])
# Out:
# <img src="data:image/gif;base64,..."/>

# %%
embed.embed_file(anim_files[3])
# Out:
# <img src="data:image/gif;base64,..."/>

# %%
embed.embed_file(anim_files[4])
# Out:
# <img src="data:image/gif;base64,..."/>
