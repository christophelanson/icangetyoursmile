# %%
from PIL import Image
import os

# %%
#/home/christophelanson/code/christophelanson/icangetyoursmile/raw_data/64x64/Mask/with-mask-default-mask-seed9429.png
#/home/christophelanson/code/christophelanson/icangetyoursmile/raw_data/Kaggle_Mask_Lite_dataset/without_mask

# %%
path_to_images = "../../raw_data/Kaggle_Mask_Lite_dataset/without_mask"
images_list = sorted(os.listdir(path_to_images))

path_to_resized_images = "../../raw_data/128x128/No_mask"
resize_size = (128,128)
nb_images = 10000
images_list
# Out:
# ['seed0000.png',
#  'seed0001.png',
#  'seed0002.png',
#  'seed0003.png',
#  'seed0004.png',
#  'seed0005.png',
#  'seed0006.png',
#  'seed0007.png',
#  'seed0008.png',
#  'seed0009.png',
#  'seed0010.png',
#  'seed0011.png',
#  'seed0012.png',
#  'seed0013.png',
#  'seed0014.png',
#  'seed0015.png',
#  'seed0016.png',
#  'seed0017.png',
#  'seed0018.png',
#  'seed0019.png',
#  'seed0020.png',
#  'seed0021.png',
#  'seed0022.png',
#  'seed0023.png',
#  'seed0024.png',
#  'seed0025.png',
#  'seed0026.png',
#  'seed0027.png',
#  'seed0028.png',
#  'seed0029.png',
#  'seed0030.png',
#  'seed0031.png',
#  'seed0032.png',
#  'seed0033.png',
#  'seed0034.png',
#  'seed0035.png',
#  'seed0036.png',
#  'seed0037.png',
#  'seed0038.png',
#  'seed0039.png',
#  'seed0040.png',
#  'seed0041.png',
#  'seed0042.png',
#  'seed0043.png',
#  'seed0044.png',
#  'seed0045.png',
#  'seed0046.png',
#  'seed0047.png',
#  'seed0048.png',
#  'seed0049.png',
#  'seed0050.png',
#  'seed0051.png',
# ...

# %%
for image in images_list:
    image_path = f'{path_to_images}/{str(image)}'
    image_HD = Image.open(image_path)
    image_LD = image_HD.resize(resize_size)
    save_path = f'{path_to_resized_images}/{image}'
    image_LD.save(save_path)
    image_LD.format
